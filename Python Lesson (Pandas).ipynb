# %% [markdown]
# <a href="https://colab.research.google.com/github/Kazureee/Python-Lessons/blob/main/Python%20Lesson%20(Pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#loading data
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
path = "/content/drive/MyDrive/Colab Notebooks/data/"

df = pd.read_csv(f'{path}Pokemon.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Reading data top
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
#Reading data bottom
df.tail(5)
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
#Read headers
df. columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#Read each columns
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
#Read each columns multiple (Nested)
df[['Name', 'Type 1', 'Legendary']]
# Out:
#                       Name   Type 1  Legendary
# 0                Bulbasaur    Grass      False
# 1                  Ivysaur    Grass      False
# 2                 Venusaur    Grass      False
# 3    VenusaurMega Venusaur    Grass      False
# 4               Charmander     Fire      False
# ..                     ...      ...        ...
# 795                Diancie     Rock       True
# 796    DiancieMega Diancie     Rock       True
# 797    HoopaHoopa Confined  Psychic       True
# 798     HoopaHoopa Unbound  Psychic       True
# 799              Volcanion     Fire       True
#
# [800 rows x 3 columns]

# %%
#Read single rows
df.iloc[4]
# Out:
# #                      4
# Name          Charmander
# Type 1              Fire
# Type 2               NaN
# Total                309
# HP                    39
# Attack                52
# Defense               43
# Sp. Atk               60
# Sp. Def               50
# Speed                 65
# Generation             1
# Legendary          False
# Name: 4, dtype: object

# %%
#Read range of rows
df.iloc[4:9]
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False

# %%
#Read a specific location(r,c)
df.iloc[6 , 1]
# Out:
# 'Charizard'

# %%
#Read a specific Column
for index, row in df.iterrows():
  print(index, row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran♀
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran♂
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# 66 Poliwhirl
# ...

# %%
#Read a multiple specific column
for index, row in df.iterrows():
  print(index, row['Name'] + ' ' + row['Type 1'])

# %%
#Sorting or describing data
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
#Sorting or describing data decending
df.sort_values('Name', ascending = False)
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 46    41                    Zubat   Poison  Flying    245   40      45
# 631  570                    Zorua     Dark     NaN    330   40      65
# 632  571                  Zoroark     Dark     NaN    510   60     105
# ..   ...                      ...      ...     ...    ...  ...     ...
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# 392  359                    Absol     Dark     NaN    465   65     130
# 68    63                     Abra  Psychic     NaN    310   25      20
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 510  460                Abomasnow    Grass     Ice    494   90      92
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#Sorting or describing data ascending
df.sort_values('Name', ascending = True)
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 510  460                Abomasnow    Grass     Ice    494   90      92
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 68    63                     Abra  Psychic     NaN    310   25      20
# 392  359                    Absol     Dark     NaN    465   65     130
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# ..   ...                      ...      ...     ...    ...  ...     ...
# 632  571                  Zoroark     Dark     NaN    510   60     105
# 631  570                    Zorua     Dark     NaN    330   40      65
# 46    41                    Zubat   Poison  Flying    245   40      45
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#Sorting or describing data ascending two or more
df.sort_values(['Name', 'Total'], ascending = [True, False])
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 510  460                Abomasnow    Grass     Ice    494   90      92
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 68    63                     Abra  Psychic     NaN    310   25      20
# 392  359                    Absol     Dark     NaN    465   65     130
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# ..   ...                      ...      ...     ...    ...  ...     ...
# 632  571                  Zoroark     Dark     NaN    510   60     105
# 631  570                    Zorua     Dark     NaN    330   40      65
# 46    41                    Zubat   Poison  Flying    245   40      45
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#Sorting or describing data ascending two or more
df.sort_values('Type 1', ascending = True)
# Out:
#        #      Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 600  540  Sewaddle    Bug     Grass    310   45      53       70       40
# 136  127    Pinsir    Bug       NaN    500   65     125      100       55
# 457  412     Burmy    Bug       NaN    224   40      29       45       29
# 132  123   Scyther    Bug    Flying    500   70     110       80       55
# 656  595    Joltik    Bug  Electric    319   50      47       50       57
# ..   ...       ...    ...       ...    ...  ...     ...      ...      ...
# 172  158  Totodile  Water       NaN    314   50      65       64       44
# 610  550  Basculin  Water       NaN    460   70      92       65       80
# 145  134  Vaporeon  Water       NaN    525  130      65       60      110
# 574  515   Panpour  Water       NaN    316   50      53       48       53
# 184  170  Chinchou  Water  Electric    330   75      38       38       56
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
#Sorting or describing data ascending two or more
df.sort_values(['Type 1', 'Attack'], ascending = [True, False])
# Out:
#        #                     Name Type 1    Type 2  Total  HP  Attack  \
# 232  214  HeracrossMega Heracross    Bug  Fighting    600  80     185
# 137  127        PinsirMega Pinsir    Bug    Flying    600  65     155
# 19    15    BeedrillMega Beedrill    Bug    Poison    495  65     150
# 229  212        ScizorMega Scizor    Bug     Steel    600  70     150
# 650  589               Escavalier    Bug     Steel    495  70     135
# ..   ...                      ...    ...       ...    ...  ..     ...
# 405  370                  Luvdisc  Water       NaN    330  43      30
# 198  183                   Marill  Water     Fairy    250  70      20
# 508  458                  Mantyke  Water    Flying    345  45      20
# 381  349                   Feebas  Water       NaN    200  20      15
# 139  129                 Magikarp  Water       NaN    200  20      10
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 232      115       40      105     75           2      False
# ...

# %%
#Sorting or describing data ascending two or more
newf = df.sort_values(['Type 1', 'Total'] , ascending = [True, False])
newf.head(1)
# Out:
#        #               Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 137  127  PinsirMega Pinsir    Bug  Flying    600  65     155      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 137       65       90    105           1      False

# %%
#Making Changes to data (remove)
df = df.drop(columns = ['Total'])
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# Restore
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
#rearrange manually
df = df[['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]
df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed
# 0         65       65     45
# 1         80       80     60
# ...

# %%
#Save data
df = pd.read_csv(f'{path}Pokemon.csv')
df = df.loc[(df['Type 1'] == 'Fire') & (df['Attack'] >= 70)]
df = df[['Name', 'Attack', 'Legendary']]
df

df = df.to_csv(f'{path}filtered.csv', index = False)
df = df.to_excel(f'{path}filtered.xlsx', index = False)
df = df.to_csv(f'{path}filtered.txt', index = False, sep = '\t')

# %%
#Filter data
fire = df.loc[(df['Type 1'] == 'Fire') & (df['Attack'] >= 70)]
fire
# Out:
#                           Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 6                    Charizard   Fire    Flying    534   78      84       78
# 7    CharizardMega Charizard X   Fire    Dragon    634   78     130      111
# 8    CharizardMega Charizard Y   Fire    Flying    634   78     104       78
# 43                   Ninetales   Fire       NaN    505   73      76       75
# 63                   Growlithe   Fire       NaN    350   55      70       45
# 64                    Arcanine   Fire       NaN    555   90     110       80
# 83                      Ponyta   Fire       NaN    410   50      85       55
# 84                    Rapidash   Fire       NaN    500   65     100       70
# 135                     Magmar   Fire       NaN    495   65      95       57
# 147                    Flareon   Fire       NaN    525   65     130       60
# 158                    Moltres   Fire    Flying    580   90     100       90
# ...

# %%
#Filter data "~" for not
df.loc[df['Name'].str.contains('Mega')]
# Out:
#                           Name    Type 1    Type 2  Total   HP  Attack  \
# 3        VenusaurMega Venusaur     Grass    Poison    625   80     100
# 7    CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8    CharizardMega Charizard Y      Fire    Flying    634   78     104
# 12     BlastoiseMega Blastoise     Water       NaN    630   79     103
# 19       BeedrillMega Beedrill       Bug    Poison    495   65     150
# 23         PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 71       AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 87         SlowbroMega Slowbro     Water   Psychic    590   95      75
# 102          GengarMega Gengar     Ghost    Poison    600   60      65
# 124  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 137          PinsirMega Pinsir       Bug    Flying    600   65     155
# 141      GyaradosMega Gyarados     Water      Dark    640   95     155
# ...

# %%
#Filter data
df.loc[df['Name'].str.contains('ion')]
# Out:
#            Name   Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 171  Typhlosion     Fire       NaN    534  78      84       78      109
# 502     Drapion   Poison      Dark    500  70      90      110       60
# 547      Phione    Water       NaN    480  80      80       80       80
# 639     Duosion  Psychic       NaN    370  65      40       50      125
# 699    Cobalion    Steel  Fighting    580  91      90      129       90
# 700   Terrakion     Rock  Fighting    580  91     129       90       72
# 701    Virizion    Grass  Fighting    580  91      90       72       90
# 799   Volcanion     Fire     Water    600  80     110      120      130
#
#      Sp. Def  Speed
# 171       85    100
# 502       75     95
# 547       80     80
# 639       60     30
# 699       72    108
# 700       90    108
# 701      129    108
# 799       90     70

# %%
#Filter data pokemon name starts with 'pi' with case sensitive , (^) means starts, (flags = re.I) means not case sensitive
import re
df.loc[df['Name'].str.contains('^pi[a-z]*', flags = re.I, regex = True)]
# Out:
#                     Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 20                Pidgey    Normal    Flying    251   40      45       40
# 21             Pidgeotto    Normal    Flying    349   63      60       55
# 22               Pidgeot    Normal    Flying    479   83      80       75
# 23   PidgeotMega Pidgeot    Normal    Flying    579   83      80       80
# 30               Pikachu  Electric       NaN    320   35      55       40
# 136               Pinsir       Bug       NaN    500   65     125      100
# 137    PinsirMega Pinsir       Bug    Flying    600   65     155      120
# 186                Pichu  Electric       NaN    205   20      40       15
# 219               Pineco       Bug       NaN    290   50      65       90
# 239            Piloswine       Ice    Ground    450  100     100       80
# 438               Piplup     Water       NaN    314   53      51       53
# 558              Pignite      Fire  Fighting    418   90      93       55
# ...

# %%
#ends with but using regex
import re
df.loc[df['Name'].str.contains('[a-z]*ion$', flags = re.I, regex = True)]
# Out:
#            Name   Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 171  Typhlosion     Fire       NaN    534  78      84       78      109
# 502     Drapion   Poison      Dark    500  70      90      110       60
# 639     Duosion  Psychic       NaN    370  65      40       50      125
# 699    Cobalion    Steel  Fighting    580  91      90      129       90
# 700   Terrakion     Rock  Fighting    580  91     129       90       72
# 701    Virizion    Grass  Fighting    580  91      90       72       90
# 799   Volcanion     Fire     Water    600  80     110      120      130
#
#      Sp. Def  Speed
# 171       85    100
# 502       75     95
# 639       60     30
# 699       72    108
# 700       90    108
# 701      129    108
# 799       90     70

# %%
#Conditional changes
df.loc[df['Type 1'] == 'Grass', 'Type 1'] = 'Halaman'
df.loc[df['Type 1'] == 'Halaman', 'Legendary'] = True
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur  Halaman  Poison    318  45      49       49
# 1      2                Ivysaur  Halaman  Poison    405  60      62       63
# 2      3               Venusaur  Halaman  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur  Halaman  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
#Aggregiete count
df =pd.read_csv(f'{path}Pokemon.csv')
df.groupby(['Type 1']).count()['Name']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: Name, dtype: int64

# %%
#Aggregiete sum
df =pd.read_csv(f'{path}Pokemon.csv')
df.groupby(['Type 1']).sum()['Attack'].sort_values(ascending = False)
# Out:
# Type 1
# Water       8305
# Normal      7200
# Grass       5125
# Bug         4897
# Fire        4408
# Rock        4086
# Psychic     4073
# Dragon      3588
# Ground      3064
# Electric    3040
# Dark        2740
# Fighting    2613
# Steel       2503
# Ghost       2361
# Poison      2091
# Ice         1746
# Fairy       1046
# Flying       315
# Name: Attack, dtype: int64

# %%
#Aggregiete sum
df =pd.read_csv(f'{path}Pokemon.csv')
df.groupby(['Type 1'])['Attack'].mean().sort_values(ascending = False)
# Out:
# Type 1
# Dragon      112.125000
# Fighting     96.777778
# Ground       95.750000
# Rock         92.863636
# Steel        92.703704
# Dark         88.387097
# Fire         84.769231
# Flying       78.750000
# Poison       74.678571
# Water        74.151786
# Ghost        73.781250
# Normal       73.469388
# Grass        73.214286
# Ice          72.750000
# Psychic      71.456140
# Bug          70.971014
# Electric     69.090909
# Fairy        61.529412
# Name: Attack, dtype: float64
